# %%
from pmbrl.data import Experiment_Data

# %%
data1 = Experiment_Data()

data1.generate_episodes(3)
data1.save(path='testing_data_short.csv')
# Out:
# /home/gui/Área de Trabalho/rlalgs/.venv/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:168: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.deprecation(
# /home/gui/Área de Trabalho/rlalgs/.venv/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:181: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.deprecation(
# /home/gui/Área de Trabalho/rlalgs/.venv/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:168: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.deprecation(
# ...

# %%
data2 = Experiment_Data()

data2.generate_episodes(10)
data2.save(path='training_data_short.csv')
# Out:
# /home/gui/Área de Trabalho/rlalgs/.venv/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:168: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.deprecation(
# /home/gui/Área de Trabalho/rlalgs/.venv/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:181: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.deprecation(
# /home/gui/Área de Trabalho/rlalgs/.venv/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:168: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.deprecation(
# ...

# %%
data2.raw_data.head()
# Out:
#    step                               s  a    r  \
# 0     0    [-0.041, 0.037, 0.015, -0.0]  0  1.0
# 1     1   [-0.04, -0.157, 0.015, 0.276]  1  1.0
# 2     2    [-0.043, 0.037, 0.02, 0.009]  1  1.0
# 3     3   [-0.042, 0.231, 0.02, -0.257]  1  1.0
# 4     4  [-0.038, 0.425, 0.015, -0.523]  0  1.0
#
#                                s_            p  episode
# 0   [-0.04, -0.157, 0.015, 0.276]  [0.24, 0.6]        0
# 1    [-0.043, 0.037, 0.02, 0.009]  [0.24, 0.6]        0
# 2   [-0.042, 0.231, 0.02, -0.257]  [0.24, 0.6]        0
# 3  [-0.038, 0.425, 0.015, -0.523]  [0.24, 0.6]        0
# 4   [-0.029, 0.23, 0.005, -0.247]  [0.24, 0.6]        0

# %%
training_data = Experiment_Data()

training_data.load(path='training_data.csv')
training_data.raw_data.head()
# Out:
#    episode  step                               s  a    r  \
# 0        0     0   (0.02, -0.037, -0.022, 0.009)  0  1.0
# 1        0     1  (0.019, -0.229, -0.022, 0.229)  0  1.0
# 2        0     2  (0.015, -0.421, -0.017, 0.449)  0  1.0
# 3        0     3  (0.006, -0.612, -0.008, 0.671)  0  1.0
# 4        0     4  (-0.006, -0.804, 0.005, 0.894)  1  1.0
#
#                                s_            p
# 0  (0.019, -0.229, -0.022, 0.229)  (0.58, 1.0)
# 1  (0.015, -0.421, -0.017, 0.449)  (0.58, 1.0)
# 2  (0.006, -0.612, -0.008, 0.671)  (0.58, 1.0)
# 3  (-0.006, -0.804, 0.005, 0.894)  (0.58, 1.0)
# 4   (-0.022, -0.612, 0.023, 0.67)  (0.58, 1.0)

# %%
testing_data = Experiment_Data()

testing_data.load(path='testing_data.csv')
testing_data.raw_data.head()
# Out:
#    episode  step                                 s  a    r  \
# 0        0     0  (-0.005, -0.042, -0.019, -0.009)  0  1.0
# 1        0     1    (-0.006, -0.233, -0.02, 0.183)  1  1.0
# 2        0     2   (-0.01, -0.042, -0.016, -0.018)  1  1.0
# 3        0     3   (-0.011, 0.149, -0.016, -0.218)  1  1.0
# 4        0     4    (-0.008, 0.34, -0.021, -0.418)  1  1.0
#
#                                 s_            p
# 0   (-0.006, -0.233, -0.02, 0.183)  (0.62, 1.2)
# 1  (-0.01, -0.042, -0.016, -0.018)  (0.62, 1.2)
# 2  (-0.011, 0.149, -0.016, -0.218)  (0.62, 1.2)
# 3   (-0.008, 0.34, -0.021, -0.418)  (0.62, 1.2)
# 4  (-0.001, 0.531, -0.029, -0.619)  (0.62, 1.2)
