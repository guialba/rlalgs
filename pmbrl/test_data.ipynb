# %%
from typing import Any, Dict
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import gymnasium as gym
import rlenvs
import pandas as pd


from pmbrl.data import Experiment_Data

# %%
data = Experiment_Data()

data.generate_episodes()
data.build_training_dataset()
# Out:
# /home/gui/Área de Trabalho/rlalgs/.venv/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:168: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.deprecation(
# /home/gui/Área de Trabalho/rlalgs/.venv/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:181: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.deprecation(
# /home/gui/Área de Trabalho/rlalgs/.venv/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:168: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.deprecation(
# ...

# %%
data.training_dataset.apply(lambda row: data.search(row, positive=True), axis=1, result_type='expand')
# Out:
#                                    s  a                              s_  \
# 0      [0.02, -0.009, 0.047, -0.014]  1    [0.02, 0.178, 0.047, -0.129]
# 1       [0.02, 0.178, 0.047, -0.129]  0   [0.023, -0.01, 0.045, -0.001]
# 2      [0.023, -0.01, 0.045, -0.001]  0   [0.023, -0.197, 0.045, 0.126]
# 3      [0.023, -0.197, 0.045, 0.126]  1     [0.019, -0.01, 0.047, 0.01]
# 4        [0.019, -0.01, 0.047, 0.01]  1   [0.019, 0.177, 0.047, -0.105]
# ...                              ... ..                             ...
# 2214  [-0.003, -0.401, 0.013, 1.007]  0  [-0.011, -0.605, 0.033, 1.492]
# 2215  [-0.011, -0.605, 0.033, 1.492]  0  [-0.023, -0.809, 0.063, 1.986]
# 2216  [-0.023, -0.809, 0.063, 1.986]  1  [-0.039, -0.607, 0.102, 1.543]
# 2217  [-0.039, -0.607, 0.102, 1.543]  0  [-0.052, -0.812, 0.133, 2.063]
# 2218  [-0.052, -0.812, 0.133, 2.063]  0  [-0.068, -1.017, 0.174, 2.592]
#
#                 p
# 0      (0.2, 1.3)
# 1      (0.2, 1.3)
# 2      (0.2, 1.3)
# 3      (0.2, 1.3)
# ...

# %%
data.training_dataset.iloc[0]
# Out:
# step                                   0
# episode                                0
# p                             (0.2, 1.3)
# s          [0.02, -0.009, 0.047, -0.014]
# a                                      1
# r                                    1.0
# s_          [0.02, 0.178, 0.047, -0.129]
# a_                                   0.0
# r_                                   1.0
# s__        [0.023, -0.01, 0.045, -0.001]
# Name: 0, dtype: object

# %%
data.search(data.training_dataset.iloc[0], positive=True)
# Out:
# s     [0.02, -0.009, 0.047, -0.014]
# a                                 1
# s_     [0.02, 0.178, 0.047, -0.129]
# p                        (0.2, 1.3)
# dtype: object
